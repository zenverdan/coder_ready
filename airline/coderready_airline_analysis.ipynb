# %% [markdown]
# # Airline Data Science Operation Day 3

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
flight = pd.read_csv("drive/MyDrive/learn/coders_ready/day_2/airline_data.csv")

# %%
flight.head()
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
# 2                UA                     19977                          UA
# 3                HP                     19991                          HP
# 4                UA                     19977                          UA
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# ...

# %%
df1 = flight.copy()

# %%
df1.count()
# Out:
# Unnamed: 0          27000
# Year                27000
# Quarter             27000
# Month               27000
# DayofMonth          27000
#                     ...
# Div5WheelsOn            0
# Div5TotalGTime          0
# Div5LongestGTime        0
# Div5WheelsOff           0
# Div5TailNum             0
# Length: 110, dtype: int64

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'FlightDate', 'Reporting_Airline', 'DOT_ID_Reporting_Airline',
#        'IATA_CODE_Reporting_Airline',
#        ...
#        'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', 'Div5AirportID',
#        'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime',
#        'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum'],
#       dtype='object', length=110)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Columns: 110 entries, Unnamed: 0 to Div5TailNum
# dtypes: float64(74), int64(19), object(17)
# memory usage: 22.7+ MB

# %%
df1.describe()
# Out:
#          Unnamed: 0          Year       Quarter         Month    DayofMonth  \
# count  2.700000e+04  27000.000000  27000.000000  27000.000000  27000.000000
# mean   9.987625e+05   2004.304926      2.505889      6.518667     15.714370
# std    5.767890e+05      9.189835      1.114589      3.444192      8.816548
# min    1.480000e+02   1987.000000      1.000000      1.000000      1.000000
# 25%    5.029945e+05   1997.000000      2.000000      4.000000      8.000000
# 50%    9.964900e+05   2005.000000      3.000000      7.000000     16.000000
# 75%    1.500778e+06   2012.000000      3.000000      9.000000     23.000000
# max    1.999844e+06   2020.000000      4.000000     12.000000     31.000000
#
#           DayOfWeek  DOT_ID_Reporting_Airline  \
# count  27000.000000              27000.000000
# mean       3.939407              19923.175222
# std        1.986853                367.912667
# min        1.000000              19386.000000
# 25%        2.000000              19704.000000
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
# 2                UA                     19977                          UA
# 3                HP                     19991                          HP
# 4                UA                     19977                          UA
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# ...

# %%
df1["Year"].value_counts()
# Out:
# 2007    1062
# 2019    1026
# 2006    1013
# 2005    1006
# 2008     988
# 2004     980
# 2018     961
# 2009     954
# 2010     950
# 2011     919
# 2003     872
# 2013     869
# 2014     853
# 2001     835
# 2015     794
# 2012     791
# 2000     785
# 1999     769
# 2017     761
# 2016     758
# 1995     746
# 1998     745
# 1988     744
# 1997     742
# 2002     730
# 1989     718
# 1992     718
# 1990     717
# 1991     712
# 1996     703
# 1994     689
# 1993     681
# 2020     232
# 1987     177
# Name: Year, dtype: int64

# %%
df1.isna().sum()
# Out:
# Unnamed: 0              0
# Year                    0
# Quarter                 0
# Month                   0
# DayofMonth              0
#                     ...
# Div5WheelsOn        27000
# Div5TotalGTime      27000
# Div5LongestGTime    27000
# Div5WheelsOff       27000
# Div5TailNum         27000
# Length: 110, dtype: int64

# %% [markdown]
# ## Drop all null column

# %%
df1.dropna(axis=1, inplace=True)

# %%
df1.shape
# Out:
# (27000, 32)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       27000 non-null  int64
#  1   Year                             27000 non-null  int64
#  2   Quarter                          27000 non-null  int64
#  3   Month                            27000 non-null  int64
#  4   DayofMonth                       27000 non-null  int64
#  5   DayOfWeek                        27000 non-null  int64
#  6   FlightDate                       27000 non-null  object
#  7   Reporting_Airline                27000 non-null  object
#  8   DOT_ID_Reporting_Airline         27000 non-null  int64
#  9   IATA_CODE_Reporting_Airline      27000 non-null  object
#  10  Flight_Number_Reporting_Airline  27000 non-null  int64
#  11  OriginAirportID                  27000 non-null  int64
# ...

# %%
df1.corr()
# Out:
# <ipython-input-26-49b3fcfeb4d1>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                                  Unnamed: 0      Year   Quarter     Month  \
# Unnamed: 0                         1.000000  0.002228 -0.014592 -0.013806
# Year                               0.002228  1.000000 -0.036146 -0.034542
# Quarter                           -0.014592 -0.036146  1.000000  0.971337
# Month                             -0.013806 -0.034542  0.971337  1.000000
# DayofMonth                        -0.001123 -0.011380  0.004675  0.002186
# DayOfWeek                          0.007904  0.001201  0.002519  0.004300
# DOT_ID_Reporting_Airline           0.005457  0.146748 -0.011575 -0.011703
# Flight_Number_Reporting_Airline    0.016698  0.373825 -0.013392 -0.011883
# ...

# %% [markdown]
# ## Find Delay average by month

# %%
flight.head()
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
# 2                UA                     19977                          UA
# 3                HP                     19991                          HP
# 4                UA                     19977                          UA
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# ...

# %%
delay = flight.groupby("Month")["ArrDelay"].mean()

# %%
sns.relplot(x='Month', y='ArrDelay', kind='line', data=monthly_delay, height=6, aspect=2, color="blue")
